# %%
import qutip as qt
import numpy as np
import matplotlib.pyplot as plt
from qutip.ipynbtools import version_table
from tqdm.notebook import tqdm
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset
from matplotlib.patches import Rectangle


resol = 300
pi = np.pi
version_table()

plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif"
})

# %% [markdown]
# <h1> RG Scheme </h1>

# %%
def update_state(c,b,g_0,omega_tab,omega_A,L,t, dt):
    """
    Update the state of the system based on the given parameters.
    
    Parameters:
    c (np array): Coefficients in front of the states |1_k, 0>
    b (float): Atomic coefficient in front of the state |0, 1>
    g_0 (float): Coupling strength.
    omega_tab (array): Array of frequencies.
    L (int): Length of the system.
    
    Returns:
    c_new (np array): Updated coefficients.
    b_new (float): Updated atomic coefficient.
    """
    g_matrix_individual = 1j * g_0 * np.sqrt(omega_A / L) * np.exp(-1j * (omega_tab - omega_A) * t)
    g_matrix = np.concatenate((g_matrix_individual, g_matrix_individual))

    b_new = c @ g_matrix
    c_new = b * np.conjugate(g_matrix)

    return -1j* dt * c_new, -1j * dt * b_new

def RG_scheme(c_init, b_init, g_0, omega_tab, omega_A, L, T, dt, progress_bar=True):
    """
    Propagates the state of the system using the RG scheme.
    
    Parameters:
    c_init (np array): initial coefficients in front of the states |1_k, 0>
    b_init (float): initial atomic coefficient in front of the state |0, 1>
    g_0 (float): Coupling strength.
    omega_tab (array): Array of frequencies.
    L (float): Length of the system.
    T (float): Total time for propagation.
    dt (float): Time step for propagation.
    
    Returns:
    c_array (np array): Array of c coefficients at each time step.
    b_array (np array): Array of b coefficients at each time step.
    """

    nb_pts_time = int(T / dt)
    n_modes = len(c_init)//2
    c_array = np.zeros((nb_pts_time, 2*n_modes), dtype=complex)
    b_array = np.zeros(nb_pts_time, dtype=complex)

    # Set the initial conditions
    c_array[0] = c_init
    b_array[0] = b_init

    # Time evolution loop
    for i in tqdm(range(1, nb_pts_time), disable=not progress_bar):
        t = i * dt
        c_current = c_array[i-1]
        b_current = b_array[i-1]

        c_new_k1, b_new_k1 = update_state(c_current, b_current, g_0, omega_tab, omega_A, L, t, dt)
        c_new_k2, b_new_k2 = update_state(c_current + c_new_k1/2, b_current + b_new_k1/2, g_0, omega_tab, omega_A, L, t + dt/2, dt)
        c_new_k3, b_new_k3 = update_state(c_current + c_new_k2/2, b_current + b_new_k2/2, g_0, omega_tab, omega_A, L, t + dt/2, dt)
        c_new_k4, b_new_k4 = update_state(c_current + c_new_k3, b_current + b_new_k3, g_0, omega_tab, omega_A, L, t + dt, dt)

        c_new = c_current + (c_new_k1 + 2*c_new_k2 + 2*c_new_k3 + c_new_k4) / 6
        b_new = b_current + (b_new_k1 + 2*b_new_k2 + 2*b_new_k3 + b_new_k4) / 6

        c_array[i] = c_new
        b_array[i] = b_new

    return c_array, b_array

# %% [markdown]
# <h1> Function that treats the whole evolution </h1>

# %%
def get_data_mirror_fast(L, T, dt, omega_0, omega_A, omega_max, g_0, sigma, x_0, print_nb_modes = False, progress_bar=True):
    """
    Generate data for the RG scheme with a mirror.
    
    Parameters:
    L (float): Length of the system.
    T (float): Total time for propagation.
    dt (float): Time step for propagation.
    omega_0 (float): Frequency of the photon
    omega_A (float): Frequency of the atom
    omega_max (float): Maximum frequency for the modes.
    g_0 (float): Coupling strength.
    sigma (float): Width of the Gaussian wave packet in position space.
    x_0 (float): Position of the Gaussian peak.
    print_nb_modes (bool): Whether to print the number of modes used.
    
    Returns:
    c_array (np array): Coefficients in front of the states |1_k, 0>.
    b_array (np array): Coefficients in front of the state |0, 1>.
    omega_tab (np array): Array of frequencies.
    """
    
    #quantization of the modes
    omega_tab_individual = np.array([2*pi*n/L for n in range(1000000) if 2*pi*n/L <= omega_max])
    k_tab_individual = np.copy(omega_tab_individual)
    n_modes = len(k_tab_individual)

    if print_nb_modes:
        print("Number of modes: ", n_modes)
    
    #prepare the initial state
    print("Preparing the initial state...")
    c_init = np.zeros(2*n_modes, dtype=complex)
    b_init = 0

    c_init_1 = np.exp(-(0.5*(k_tab_individual - omega_0)**2) * sigma**2) * np.exp(-1j * k_tab_individual * x_0)
    c_init = np.concatenate((c_init_1, np.zeros(n_modes))) #only one photon in the first channel
    c_init /= np.sqrt(np.sum(np.abs(c_init)**2))  # Normalize the initial state

    ##evolve the state
    print("Evolving the state...")
    c_array, b_array = RG_scheme(c_init, b_init, g_0, omega_tab_individual, omega_A, L, T, dt, progress_bar=progress_bar)


    return c_array, b_array, k_tab_individual

###For comparison with ED

def get_data_mirror_ed(L, T, dt, omega_0, omega_A, omega_max, g_0, sigma, x_0, print_nb_modes = False):
    #quantization of the modes
    omega_tab_individual = np.array([2*pi*n/L for n in range(1000000) if 2*pi*n/L <= omega_max])
    k_tab_individual = np.copy(omega_tab_individual)
    n_modes = len(k_tab_individual)

    if print_nb_modes:
        print("Number of modes: ", n_modes)

    #Creation of the Hamiltonian
    dim_subspace = 2*n_modes + 1
    H_matrix = np.zeros((dim_subspace, dim_subspace), dtype=complex)

    print("Preparing the Hamiltonian ...")
    for i in range(n_modes):

        #diagonal elements
        H_matrix[i, i] = omega_tab_individual[i]
        H_matrix[i+n_modes, i+n_modes] = omega_tab_individual[i]

        #off diagonal elements
        H_matrix[2*n_modes,i] = 1j*g_0*np.sqrt(omega_A/L)
        H_matrix[2*n_modes, i+n_modes] = 1j*g_0*np.sqrt(omega_A/L)

        H_matrix[i,2*n_modes] = -1j*g_0*np.sqrt(omega_A/L)
        H_matrix[i+n_modes, 2*n_modes] = -1j*g_0*np.sqrt(omega_A/L)

    H_matrix[2*n_modes, 2*n_modes] = omega_A

    H = qt.Qobj(H_matrix)
    #hermicity check
    if not H.isherm:
        print("Hermicity of the Hamiltonian: ", H.isherm)
        return None
    
    #also obtain the free hamiltonian
    H_free = qt.Qobj(np.diag(np.diag(H_matrix)))

    print("Initializing the state ...")
    ##Initial state

    init_state = 0
    for i in range(n_modes): ##only the modes in the first waveguide
        coef = np.exp(-0.5*sigma**2*(k_tab_individual[i] - omega_0)**2 -1j * k_tab_individual[i] * x_0)
        init_state += coef * qt.basis(dim_subspace, i)
    init_state = init_state.unit()
    
    print("Launching the time evolution ...")
    #time evolution
    n_step = int(T/dt)
    times = np.linspace(0, T, n_step)
    result = qt.sesolve(H, init_state, times, options={"nsteps":10000, "progress_bar": True, "store_states": True})
    state_list = result.states
    
    return times, state_list

# %% [markdown]
# <h1> First test </h1>

# %%
L = 10*pi
T = L/2
dt = 0.1

#Jaynes-Cummings parameter g_0 and energies 
g_0 = 1
omega_A = 10
omega_0 = 10
gamma = g_0**2 * omega_A

omega_max = 20

#initial photon wavepacket parameters
sigma = L/16
sigma_momentum = 1/sigma
x_0 = -L/4

#check some parameters
print("50% Reflectivity for omega_0_m = ", omega_A - gamma, " and omega_0_p = ", omega_A + gamma)
print("Value of gamma", gamma, "and sigma_momentum = ", sigma_momentum)
# Out:
# 50% Reflectivity for omega_0_m =  0  and omega_0_p =  20
# Value of gamma 10 and sigma_momentum =  0.5092958178940651

# %%
c_array, b_array, k_tab = get_data_mirror_fast(L, T, dt, omega_0, omega_A, omega_max, g_0, sigma, x_0, print_nb_modes=True)

#ED comparision
ed = True

if ed:
    dt_ed = 0.01
    print("Exact diagonalization...")
    times_ed, state_list_ed = get_data_mirror_ed(L, T, dt_ed, omega_0, omega_A, omega_max, g_0, sigma, x_0, print_nb_modes = True)
# Out:
# Number of modes:  101
# Preparing the initial state...
# Evolving the state...
#   0%|          | 0/156 [00:00<?, ?it/s]
# Exact diagonalization...
# Number of modes:  101
# Preparing the Hamiltonian ...
# Initializing the state ...
# Launching the time evolution ...
# 10.0%. Run time:   0.01s. Est. time left: 00:00:00:00
# 20.0%. Run time:   0.02s. Est. time left: 00:00:00:00
# 30.0%. Run time:   0.03s. Est. time left: 00:00:00:00
# 40.0%. Run time:   0.04s. Est. time left: 00:00:00:00
# 50.0%. Run time:   0.05s. Est. time left: 00:00:00:00
# 60.0%. Run time:   0.06s. Est. time left: 00:00:00:00
# 70.0%. Run time:   0.07s. Est. time left: 00:00:00:00
# 80.1%. Run time:   0.09s. Est. time left: 00:00:00:00
# 90.1%. Run time:   0.09s. Est. time left: 00:00:00:00
# 100.0%. Run time:   0.10s. Est. time left: 00:00:00:00
# Total run time:   0.10s

# %% [markdown]
# <h1> Occupation numbers </h1>

# %%
time_array = np.linspace(0, T, int(T / dt))
# Prepare the k_tab for occupation numbers
n_modes = c_array.shape[1] //2
nb_pts_time = int(T / dt)

p_1 = np.zeros(nb_pts_time)
p_2 = np.zeros(nb_pts_time)
p_atom =  np.zeros(nb_pts_time)

for i in tqdm(range(nb_pts_time)):
    p_1[i] = np.sum(np.abs(c_array[i,:n_modes])**2)
    p_2[i] = np.sum(np.abs(c_array[i,n_modes:])**2)
    p_atom[i] = np.abs(b_array[i])**2  

#comparing with ed
nb_pts_time_ed = len(times_ed)
p_1_ed = np.zeros(nb_pts_time_ed)
p_2_ed = np.zeros(nb_pts_time_ed)
p_atom_ed =  np.zeros(nb_pts_time_ed)

for i in tqdm(range(nb_pts_time_ed)):
    current_state = state_list_ed[i].full().reshape(2*n_modes+1)
    p_1_ed[i] = np.sum(np.abs(current_state[:n_modes]**2))
    p_2_ed[i] = np.sum(np.abs(current_state[n_modes:2*n_modes]**2))
    p_atom_ed[i] = np.abs(current_state[2*n_modes]**2)
# Out:
#   0%|          | 0/157 [00:00<?, ?it/s]
#   0%|          | 0/1570 [00:00<?, ?it/s]

# %%
print("Reflection probability =", 1-p_1[-1])
print("Final atom's exctation probability: ", 1-p_1[-1]-p_2[-1])

fig, ax = plt.subplots(1,1, figsize=(3,3), dpi=resol)

step_to_show = 10

ax.scatter(time_array[::step_to_show], p_1[::step_to_show], label=r'$P_1(t)$', color='#bb000b', zorder = 1)
ax.scatter(time_array[::step_to_show], p_2[::step_to_show], label=r'$P_2(t)$', color='#006cbf', zorder=1)

ax.plot(times_ed, p_1_ed, color='#6d0303', alpha=0.6, zorder = -1)
ax.plot(times_ed, p_2_ed,color='#1c556d', alpha=0.6, zorder = -1)

ax.set_xlabel('Time (a.u)')
ax.set_ylabel('Probability')
ax.set_ylim(-0.1,1.1)
ax.legend(prop={'size': 10})

#font size
for item in [ax.xaxis.label, ax.yaxis.label]:
    item.set_fontsize(15)

for item in (ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(15)


ax.grid()
ax.set_axisbelow(True)  

plt.tight_layout()
plt.savefig("./fig/one_photon_ex_p1p2.pdf")
plt.show()
# Out:
# Reflection probability = 0.9998248756357916
# Final atom's exctation probability:  -0.0002505881673456889

# %%
fig, ax = plt.subplots(1,1, figsize=(3,3), dpi=resol)

step_to_show = 10
ax.scatter(time_array[::step_to_show], p_atom[::step_to_show], label=r'$|b(t)|^2$', color='#2c7b13')   
ax.plot(times_ed, p_atom_ed,color='#174708', alpha=0.6, zorder=-1) 


#ax.set_ylim(-0.1,1.1)
ax.set_xlabel('Time (a.u)')
ax.set_ylabel('Probability')

#font size
for item in [ax.xaxis.label, ax.yaxis.label]:
    item.set_fontsize(15)

for item in (ax.get_xticklabels() + ax.get_yticklabels()):
    item.set_fontsize(15)


ax.grid()
ax.set_axisbelow(True)  
ax.set_ylim(-0.1,1.1)


# Create an inset axes [x0, y0, width, height] in axes coordinates
axins = inset_axes(ax, width="40%", height="40%", loc='upper right')

# Zoom range near zero
axins.scatter(time_array[::step_to_show], p_atom[::step_to_show], color='#2c7b13')   
axins.plot(times_ed, p_atom_ed,color='#174708', alpha=0.6, zorder=-1) 
axins.set_xlim(L/8, 3*L/8)
axins.set_ylim(-0.01, 0.04)  # slightly higher for clarity
axins.grid()

rect = Rectangle((L/8, -0.03), L/4, 0.1, linewidth=1, edgecolor='black', linestyle='--', facecolor='none')
ax.add_patch(rect)
ax.plot([L/8, 1.15*L/4], [0.07, 0.58], '--', color='black', lw=0.8)
ax.plot([3*L/8, 1.37*3*L/8], [0.07, 0.58], '--', color='black', lw=0.8)

ax.legend(prop={'size': 10}, loc="upper left")

plt.tight_layout()
plt.savefig("./fig/one_photon_ex_b.pdf")
plt.show()
# Out:
# /var/folders/ds/7w970h197d59hh_2dj4ry5qw0000gn/T/ipykernel_5090/2712290970.py:42: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# <h1> UV-cutoff check </h1>
#
# I consider the incoming photon at reasonance with the atom and check the reflection probability against the UV-cutoff

# %%
L = 10*pi
T = L/2
dt = 0.01

#Jaynes-Cummings parameter g_0 and energies 
g_0 = 0.3
omega_A = 40
omega_0 = 40
gamma = g_0**2 * omega_A

nb_freq = 50
p_1_tab = np.zeros(nb_freq)
omega_max_tab = np.linspace(omega_A, 5*omega_A, nb_freq)

#initial photon wavepacket parameters
sigma = L/8
sigma_momentum = 1/sigma
x_0 = -L/4


for i in tqdm(range(nb_freq)):
    omega_max = omega_max_tab[i]
    print(f"Running for omega_max = {omega_max}")
    c_array, b_array, overlap_tab, k_tab = get_data_mirror_fast(L, T, dt, omega_0, omega_A, omega_max, g_0, sigma, x_0, print_nb_modes=False, progress_bar=False)
    n_modes = len(k_tab)
    p_1_tab[i] = np.sum(np.abs(c_array[-1, :n_modes])**2)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# Running for omega_max = 40.0
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 43.265306122448976
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 46.53061224489796
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 49.79591836734694
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 53.06122448979592
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 56.326530612244895
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 59.59183673469388
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 62.85714285714286
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 66.12244897959184
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 69.38775510204081
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 72.65306122448979
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 75.91836734693878
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 79.18367346938776
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 82.44897959183673
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 85.71428571428572
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 88.9795918367347
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 92.24489795918367
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 95.51020408163265
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 98.77551020408163
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 102.04081632653062
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 105.3061224489796
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 108.57142857142857
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 111.83673469387756
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 115.10204081632654
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 118.36734693877551
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 121.63265306122449
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 124.89795918367346
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 128.16326530612247
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 131.42857142857144
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 134.69387755102042
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 137.9591836734694
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 141.22448979591837
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 144.48979591836735
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 147.75510204081633
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 151.0204081632653
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 154.28571428571428
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 157.55102040816325
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 160.81632653061223
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 164.08163265306123
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 167.3469387755102
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 170.6122448979592
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 173.87755102040816
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 177.14285714285714
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 180.40816326530611
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 183.67346938775512
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 186.9387755102041
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 190.20408163265307
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 193.46938775510205
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 196.73469387755102
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_max = 200.0
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...

# %%
fig, ax = plt.subplots(1,1, figsize=(4,4), dpi=resol)
ax.scatter(omega_max_tab, 1-p_1_tab, marker='o', color="royalblue", label='Reflection coefficient', s=10)
ax.set_xlabel(r'$\omega_{max}$')

#set of interesting frequencies
ax.vlines(omega_A, 0, 3, color='#246d11', alpha=0.5, label=r'$\omega_A$')
ax.vlines(omega_A + gamma, 0, 3, color='#6d4e0f', alpha=0.5, label=r'$\omega_A + \gamma$')

#best UV-cutoff
index_best = np.argmin(p_1_tab)
omega_max_best = omega_max_tab[index_best]

ax.vlines(omega_max_best, 0, 3, color='red', alpha=0.9, label=r'$\omega_{max, best}$')
print("Omega max best =", omega_max_best)

ax.set_ylabel('Final reflection value')
ax.set_ylim(0, 1.1)
ax.grid()
ax.legend()
plt.show()
# Out:
# Omega max best = 79.18367346938776

# %% [markdown]
# <h1> Reflection against detunning </h1>

# %%
L = 10*pi
T = L/2
dt = 0.01

#Jaynes-Cummings parameter g_0 and energies 
g_0 = 0.5
omega_A = 10
#omega_max = omega_A + 3*gamma
omega_max = 20
print("Omega_max = ", omega_max)

#initial photon wavepacket parameters
sigma = L/8
sigma_momentum = 1/sigma
x_0 = -L/4

gamma = g_0**2 * omega_A
print("50% Reflectivity for omega_0_m = ", omega_A - gamma, " and omega_0_p = ", omega_A + gamma)
print("Value of sigma ", sigma, " and life time of the excited state: ", 1/gamma)
# Out:
# Omega_max =  20
# 50% Reflectivity for omega_0_m =  7.5  and omega_0_p =  12.5
# Value of sigma  3.9269908169872414  and life time of the excited state:  0.4

# %% [markdown]
# Run the calculations

# %%
#get the number of modes
nb_freq = 39

omega_0_tab = np.linspace(max(omega_A - 2*gamma, 0), min(omega_A + 2*gamma, 0.8*omega_max), nb_freq)
#omega_0_tab = [1]
p_1_tab = np.zeros(nb_freq)

for i in tqdm(range(nb_freq)):
    omega_0 = omega_0_tab[i]
    print(f"Running for omega_0 = {omega_0}")
    c_array, b_array, overlap_tab, k_tab = get_data_mirror_fast(L, T, dt, omega_0, omega_A, omega_max, g_0, sigma, x_0, print_nb_modes=False, progress_bar=False)
    n_modes = len(k_tab)
    p_1_tab[i] = np.sum(np.abs(c_array[-1, :n_modes])**2)
# Out:
#   0%|          | 0/39 [00:00<?, ?it/s]
# Running for omega_0 = 5.0
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 5.2631578947368425
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 5.526315789473684
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 5.7894736842105265
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 6.052631578947368
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 6.315789473684211
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 6.578947368421053
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 6.842105263157895
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 7.105263157894736
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 7.368421052631579
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 7.631578947368421
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 7.894736842105263
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 8.157894736842106
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 8.421052631578947
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 8.68421052631579
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 8.947368421052632
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 9.210526315789473
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 9.473684210526315
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 9.736842105263158
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 10.0
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 10.263157894736842
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 10.526315789473685
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 10.789473684210526
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 11.052631578947368
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 11.31578947368421
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 11.578947368421051
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 11.842105263157894
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 12.105263157894736
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 12.368421052631579
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 12.631578947368421
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 12.894736842105264
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 13.157894736842104
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 13.421052631578947
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 13.68421052631579
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 13.947368421052632
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 14.210526315789473
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 14.473684210526315
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 14.736842105263158
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# Running for omega_0 = 15.0
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...

# %%
fig, ax = plt.subplots(1,1, figsize=(4,4), dpi=resol)
ax.scatter(omega_0_tab, 1-p_1_tab, marker='o', color="royalblue", label='Reflection coefficient')
ax.legend()
ax.set_xlabel(r'$\omega_0$')
ax.set_ylabel('Final reflection value')
ax.vlines(omega_A, 0, 3, color='#246d11', alpha=0.5, label=r'$\omega_A$')
ax.set_ylim(0, 1.1)
ax.grid()
plt.show()

# %% [markdown]
# <h1> Find physical parameters </h1>

# %%
#first, find the frequency that maximizes the reflection
omega_1_index = np.argmin(np.abs(p_1_tab))
omega_1 = omega_0_tab[omega_1_index]

#then, find the frequency that matches 50% reflection
omega_2_index = np.argmin(np.abs(p_1_tab - 0.5))
omega_2 = omega_0_tab[omega_2_index]

omega_A_phys = omega_1
gamma_phys = np.abs(omega_2 - omega_A_phys)
g_0_phys = np.sqrt(gamma_phys / omega_A_phys)

#sanity check
if 1-p_1_tab[omega_1_index] < 0.99:
    print("WARNING : Reflection not high enough at resonance. Maximal value reached =", 1-p_1_tab[omega_1_index])


print("Omega_A phys :", omega_A_phys)
print("g_0 phys :", g_0_phys)
# Out:
# Omega_A phys : 10.0
# g_0 phys : 0.5380275868489705

# %% [markdown]
# Compute the corresponding theoretical predicitions to check consistency

# %%
omega_0_tab_theory = np.linspace(max(omega_A - 2*gamma, 0), omega_A + 2*gamma, 100)
omega_0_tab_simu = np.array([2*pi*n/L for n in range(1000000) if 2*pi*n/L <= omega_max])

theory_curve = 1 / (1 + (omega_0_tab_theory - omega_A_phys)**2 / (g_0_phys**2 * omega_A_phys)**2)

theory_curve_non_mono = np.zeros(100)

for i in range(100):
    omega_0_init = omega_0_tab_theory[i]

    c_init = np.exp(-(0.5*(omega_0_tab_simu - omega_0_init)**2) * sigma**2) * np.exp(-1j * omega_0_tab_simu * x_0)
    c_init /= np.sqrt(np.sum(np.abs(c_init)**2))

    r_tab_simu = 1 / (1 + (omega_0_tab_simu - omega_A_phys)**2 / (g_0_phys**2 * omega_A_phys)**2)
    reflection_coef = np.sum(np.abs(c_init)**2 * r_tab_simu)
    theory_curve_non_mono[i] = reflection_coef

# %%
fig, ax = plt.subplots(1,1, figsize=(4,4), dpi=resol)
ax.scatter(omega_0_tab, 1-p_1_tab, marker='o', color="royalblue", label='Reflection coefficient')
ax.plot(omega_0_tab_theory, theory_curve, color="green", alpha=0.5, label="monochr")
ax.plot(omega_0_tab_theory, theory_curve_non_mono, color="red", alpha=0.5, label="non monochr")
ax.legend()
ax.set_xlabel(r'$\omega_0$')
ax.set_ylabel('Final reflection value')
ax.set_ylim(0, 1.1)
ax.grid()
plt.show()

# %% [markdown]
# Check the reflection coef at 50:50 BS

# %%
omega_0_p = omega_A_phys + 1*g_0_phys**2 * omega_A_phys 

c_array, b_array, overlap_tab, k_tab = get_data_mirror_fast(L, T, dt, omega_0_p, omega_A, omega_max, g_0, sigma, x_0, print_nb_modes=False, progress_bar=False)
n_modes = len(k_tab)
p_transmission = np.sum(np.abs(c_array[-1, :n_modes])**2) 

print("At omega_0 =",  omega_0_p ," R = ", 1-p_transmission)
# Out:
# Preparing the initial state...
# Evolving the state...
# Computing overlap with the initial state...
# At omega_0 = 12.894736842105264  R =  0.5139621789049551
